# %% [markdown]
# # Ejercicios repaso python

# %% [markdown]
# 1. Declara una variable entera y otra flotante, y suma ambas.

# %%
#respuesta acá

# %% [markdown]
# 2. Utiliza el operador módulo para determinar el resto de dividir 17 entre 5.

# %%
#respuesta acá

# %% [markdown]
# 3. Convierte el string '42' a entero y el string '3.14' a flotante.

# %%
#respuesta acá

# %% [markdown]
# 4. Evalúa y guarda en una variable el resultado de la comparación encadenada: 18 <= 25 <= 65.

# %%
#respuesta acá

# %% [markdown]
# 5. Crea un string de múltiples líneas y obtén su longitud con len().

# %%
#respuesta acá

# %% [markdown]
# 6. Extrae los primeros 4 caracteres del string 'Programacion' utilizando slicing.

# %%
#respuesta acá

# %% [markdown]
# 7. Invierte el string 'Python' usando slicing con paso negativo.

# %%
#respuesta acá

# %% [markdown]
# 8. Convierte el string 'Python para Algoritmos' a minúsculas usando el método adecuado.

# %%
#respuesta acá

# %% [markdown]
# 9. Divide el string 'Ana, 22, Rancagua' en una lista utilizando el método split().

# %%
#respuesta acá

# %% [markdown]
# 10. Une la lista ['Python', 'es', 'legible'] en un solo string separado por espacios usando join().

# %%
#respuesta acá

# %% [markdown]
# 11. Crea una lista 'ciudades' con 'Rancagua', 'Santiago' y 'Talca', y accede al último elemento usando un índice negativo.

# %%
#respuesta acá

# %% [markdown]
# 12. Reemplaza el segundo elemento de la lista 'ciudades' por 'San Fernando'.

# %%
#respuesta acá

# %% [markdown]
# 13. Agrega el número 6.7 al final de la lista de notas [5.5, 6.0] usando append().

# %%
#respuesta acá

# %% [markdown]
# 14. Extiende la lista [1, 2] con los elementos de la lista [3, 4] usando extend().

# %%
#respuesta acá

# %% [markdown]
# 15. Inserta el número 20 en la posición 1 de la lista [10, 30].

# %%
#respuesta acá

# %% [markdown]
# 16. Elimina el primer elemento de la lista [10, 20, 30] usando la palabra reservada del.

# %%
#respuesta acá

# %% [markdown]
# 17. Obtén una nueva lista ordenada a partir de [8, 3, 5, 1] usando la función sorted().

# %%
#respuesta acá

# %% [markdown]
# 18. Crea una comprensión de lista que contenga los cuadrados de los números del 0 al 5.

# %%
#respuesta acá

# %% [markdown]
# 19. Crea una tupla 'punto' con los valores (10, 20) y desempaquétala en las variables x e y.

# %%
#respuesta acá

# %% [markdown]
# 20. Crea un diccionario 'estudiante' con las claves 'nombre' y 'edad', y sus respectivos valores.

# %%
#respuesta acá

# %% [markdown]
# 21. Intenta acceder a la clave 'ciudad' del diccionario 'estudiante' de forma segura usando get(), retornando 'No informada' por defecto.

# %%
#respuesta acá

# %% [markdown]
# 22. Añade la clave 'ciudad' con el valor 'Rancagua' al diccionario 'estudiante'.

# %%
#respuesta acá

# %% [markdown]
# 23. Elimina la clave 'edad' del diccionario usando el método pop().

# %%
#respuesta acá

# %% [markdown]
# 24. Recorre las claves y valores del diccionario 'estudiante' usando un bucle for y el método items().

# %%
#respuesta acá

# %% [markdown]
# 25. Crea un conjunto vacío usando la función set() y agrégale el número 4 con el método add().

# %%
#respuesta acá

# %% [markdown]
# 26. Encuentra la unión de los conjuntos a = {1, 2, 3} y b = {3, 4, 5}.

# %%
#respuesta acá

# %% [markdown]
# 27. Encuentra la intersección de los conjuntos a = {1, 2, 3, 4} y b = {3, 4, 5, 6}.

# %%
#respuesta acá

# %% [markdown]
# 28. Evalúa si la extensión 'csv' pertenece al conjunto {'csv', 'txt', 'json'} usando el operador in.

# %%
#respuesta acá

# %% [markdown]
# 29. Copia superficialmente la lista a = [1, 2, 3] en una variable b usando el método copy() y comprueba si a is b.

# %%
#respuesta acá

# %% [markdown]
# 30. Escribe un bloque if/elif/else que asigne 'Aprobado' si una nota es mayor o igual a 4.0, o 'Reprobado' en caso contrario.

# %%
#respuesta acá

# %% [markdown]
# 31. Utiliza un bucle for y la función range() para iterar del 10 al 2 (descendiendo de 2 en 2).

# %%
#respuesta acá

# %% [markdown]
# 32. Utiliza enumerate() para iterar sobre la lista ['A', 'B', 'C'] empezando el índice en 1.

# %%
#respuesta acá

# %% [markdown]
# 33. Recorre paralelamente las listas ['Ana', 'Luis'] y [6.1, 5.4] utilizando la función zip().

# %%
#respuesta acá

# %% [markdown]
# 34. Crea un ciclo while que incremente una variable de 0 hasta 4, imprimiendo su valor en cada paso.

# %%
#respuesta acá

# %% [markdown]
# 35. Define una función 'saludar' que reciba un 'nombre' y un parámetro por defecto 'saludo' igual a 'Hola', y retorne el mensaje.

# %%
#respuesta acá

# %% [markdown]
# 36. Define una función que reciba dos parámetros ('base' y 'altura') y retorne el área de un rectángulo.

# %%
#respuesta acá

# %% [markdown]
# 37. Define una función que reciba una lista de valores y retorne una tupla con el mínimo y máximo de la lista (usando min() y max()).

# %%
#respuesta acá

# %% [markdown]
# 38. Escribe un bloque try/except que capture un ValueError al intentar ejecutar int('hola').

# %%
#respuesta acá

# %% [markdown]
# 39. Define una función que divida dos números, lanzando una excepción ValueError con 'raise' si el divisor es cero.

# %%
#respuesta acá
